# %%
def square(n):
    for i in range:
        yield i**3

# %%
square(3)
# Out:
# <generator object square at 0x11147de50>

# %%
for i in square(3):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 for i in square(3):
#       2     print(i)
#
# Cell In[6], line 2, in square(n)
#       1 def square(n):
# ----> 2     for i in range:
#       3         yield i**3
#
# TypeError: 'type' object is not iterable
