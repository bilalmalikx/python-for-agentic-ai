# %%
class person:
    def __init__(self,name,age):
        self.name = name          #public attribute
        self.age = age            
        
    def get_name(Persom):
        return Person.name

person1 = person("Bilal", 25)
print(person1.name)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_person__age',
#  '_person__name',
#  'get_name']

# %%
dir(person1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
class Person:
    def __init__(self, name, age, gender):
        self.__name = name
        self.__age = age
        self.gender = gender
        
    def get_name(self):  # proper getter method
        return self.__name

person1 = Person("Bilal", 25, "Male")
print(person1.get_name())  # ✅ Output: Bilal
# Out:
# Bilal

# %%
class Person:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age

    def get_name(self):
        return self.__name

    def set_name(self, name):
        self.__name = name

    def get_age(self):   # Add this method to get age
        return self.__age

    def set_age(self, age):
        if age > 0:
            self.__age = age
        else:
            print("Age cannot be negative")

# Usage
person = Person("Bilal", 18)

print(person.get_name())   #  Calling method with parentheses
print(person.get_age())    #  Using get_age instead of set_age

person.set_age(23)         #  Update age
print(person.get_age())    #  Print updated age
# Out:
# Bilal
# 18
# 23

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age  # public attribute

person = Person("Ali", 25)
print(person.age)  # Accessing directly
person.age = -5    # Invalid age (no protection)
print(person.age)
# Out:
# 25
# -5

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.__age = age  # private attribute

    def get_age(self):
        return self.__age
    
    def set_age(self, age):
        if age > 0:
            self.__age = age
        else:
            print("Invalid age")

person = Person("Ali", 25)
print(person.get_age())   # ✔️ Safe access
person.set_age(-5)        # ❌ Invalid input
print(person.get_age())   # ✔️ Still safe value
