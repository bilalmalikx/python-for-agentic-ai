# %%
my_list = [1,2,3,4,5]

for i in my_list:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
print(my_list)
type(my_list)
# Out:
# [1, 2, 3, 4, 5]
# list

# %%
iterator = iter(my_list)
print(type(iterator))
print(next(iterator))
print(next(iterator))
print(next(iterator))
print(next(iterator))
print(next(iterator))
# Out:
# <class 'list_iterator'>
# 1
# 2
# 3
# 4
# 5

# %%
iterator = iter(my_list)

try:
    print(next(iterator))
except StopIteration:
    print("Reached the end of the iterator.")
# Out:
# 1
